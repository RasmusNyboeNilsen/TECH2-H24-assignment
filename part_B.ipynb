# %%
import numpy as np
import timeit
import pandas as pd

df = pd.read_csv('data.csv')
row1 = df.iloc[:100,0]
row2 = df.iloc[:1000,1]
row3 = df.iloc[:10000,2]


def std_loops(x): 
    x_sum = 0
    for i in x:  # Finding x mean
        x_sum = x_sum + i
    x_mean = (1/len(x))*x_sum 
    
    x_squared_sum = 0
    for i in x: # Finding the mean of squares
        x_squared_sum += i**2
    s_mean = x_squared_sum/len(x)
    
    variance = s_mean - x_mean**2

    sd = variance**0.5
    
    return sd


def std_builtin(x):
    x_sum = sum(x)
    x_mean = x_sum/len(x)
    
    x_squared_sum = sum(i**2 for i in x)
    s_mean = x_squared_sum/len(x)
    
    variance = s_mean - x_mean**2
    
    sd = variance**0.5
    
    return sd


# Finding time for row1
print("Time for row1 using loops")
# %timeit std_loops(row1)
print("\n Time for row1 using num")
# %timeit std_builtin(row1)
print("\n Time for row1 using std command")
# %timeit np.std(row1)

# Finding time for row2
print("\nTime for row2 using loops")
# %timeit std_loops(row2)
print("\nTime for row2 using num")
# %timeit std_builtin(row2)
print("\nTime for row2 using std command")
# %timeit np.std(row2)

# Finding time for row3
print("\nTime for row3 using loops")
# %timeit std_loops(row3)
print("\nTime for row3 using num")
# %timeit std_builtin(row3)
print("\nTime for row3 using std command")
# %timeit np.std(row3)
# Out:
# Time for row1 using loops
# 70.3 μs ± 2.81 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
#
#  Time for row1 using num
# 65.2 μs ± 9.93 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
#
#  Time for row1 using std command
# 15 μs ± 320 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
#
# Time for row2 using loops
# 424 μs ± 13.2 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
#
# Time for row2 using num
# 555 μs ± 91.5 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
#
# Time for row2 using std command
# 19.4 μs ± 2.75 μs per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
#
# Time for row3 using loops
# 4.63 ms ± 357 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# Time for row3 using num
# 4.57 ms ± 384 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# Time for row3 using std command
# 34.6 μs ± 3.44 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
